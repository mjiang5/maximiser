# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re   

# %matplotlib inline

# %%
bonus_posts_df = pd.read_csv('../data/bonus_post.csv')
bonus_posts_df = bonus_posts_df.iloc[:, 1:]

# %% [markdown]
# #### get bonus amount from glance

# %%
bonus_posts_df.head()
# Out:
#                                                title  \
# 0                Chesapeake Bank $100 Savings Bonus
# 1          Arsenal Credit Union $100 Checking Bonus
# 2           The Cooperative Bank $200 Checking Bonus
# 3                Old Second Bank $200 Checking Bonus
# 4  BBVA $400 Checking Bonus + $50 Savings Bonus &...
#
#                                            post_link  \
# 0  https://www.doctorofcredit.com/va-only-chesape...
# 1  https://www.doctorofcredit.com/mo-only-arsenal...
# 2  https://www.doctorofcredit.com/ma-only-the-coo...
# 3  https://www.doctorofcredit.com/il-only-old-sec...
# 4  https://www.doctorofcredit.com/bbva-400-checki...
#
#                                               glance  \
# 0  Maximum bonus amount: $100\nAvailability: VA o...
# 1  Maximum bonus amount: $100\nAvailability: MO o...
# 2  Maximum bonus amount: $200\nAvailability: MA o...
# 3  Maximum bonus amount: $200\nAvailability:Must ...
# 4  Maximum bonus amount: $450\nAvailability: Nati...
#
#                                                offer  \
# 0  Chesapeake Bank is offering a bonus of $100 wh...
# 1  Arsenal Credit Union is offering a bonus of $1...
# 2  The Cooperative Bank is offering a bonus of $2...
# 3  Old Second Bank is offering a $200 checking bo...
# 4  BBVA Compass is offering a checking bonus of $...
#
#                                                  fee
# 0  The totally free checking account has no month...
# 1  This account has no monthly fees to worry abou...
# 2  This account has a $10 monthly fee, this is wa...
# 3  Money connection account has a $3.95 fee if yo...
# 4  If you live in AL, AZ, CA, CO, FL NM or TX the...

# %%
def get_bonus_from_glance(glance):
    try:
        bonus_amount = re.search(r'bonus amount:.*\$\d+.*', glance, re.I)
        bonus_amount = re.sub(r'\,', '', bonus_amount.group(), re.I)
        bonus_amount = re.findall(r'(\$\d+)', bonus_amount, re.I)
        
        for i in range(len(bonus_amount)):
            bonus_amount[i] = re.sub(r'\$', '', bonus_amount[i])
        bonus_amount = np.max(list(map(float, bonus_amount)))
        return bonus_amount
    except:
        return np.nan

bonus_posts_df['bonus'] = bonus_posts_df['glance'].apply(get_bonus_from_glance)

# %%
bonus_posts_df.head()
# Out:
#                                                title  \
# 0                Chesapeake Bank $100 Savings Bonus
# 1          Arsenal Credit Union $100 Checking Bonus
# 2           The Cooperative Bank $200 Checking Bonus
# 3                Old Second Bank $200 Checking Bonus
# 4  BBVA $400 Checking Bonus + $50 Savings Bonus &...
#
#                                            post_link  \
# 0  https://www.doctorofcredit.com/va-only-chesape...
# 1  https://www.doctorofcredit.com/mo-only-arsenal...
# 2  https://www.doctorofcredit.com/ma-only-the-coo...
# 3  https://www.doctorofcredit.com/il-only-old-sec...
# 4  https://www.doctorofcredit.com/bbva-400-checki...
#
#                                               glance  \
# 0  Maximum bonus amount: $100\nAvailability: VA o...
# 1  Maximum bonus amount: $100\nAvailability: MO o...
# 2  Maximum bonus amount: $200\nAvailability: MA o...
# 3  Maximum bonus amount: $200\nAvailability:Must ...
# 4  Maximum bonus amount: $450\nAvailability: Nati...
#
#                                                offer  \
# 0  Chesapeake Bank is offering a bonus of $100 wh...
# 1  Arsenal Credit Union is offering a bonus of $1...
# 2  The Cooperative Bank is offering a bonus of $2...
# 3  Old Second Bank is offering a $200 checking bo...
# 4  BBVA Compass is offering a checking bonus of $...
#
#                                                  fee  bonus
# 0  The totally free checking account has no month...  100.0
# 1  This account has no monthly fees to worry abou...  100.0
# 2  This account has a $10 monthly fee, this is wa...  200.0
# 3  Money connection account has a $3.95 fee if yo...  200.0
# 4  If you live in AL, AZ, CA, CO, FL NM or TX the...  450.0

# %% [markdown]
# #### get monthly direct deposit from glance

# %%
def get_dd_from_glance(glance):
    try:
        dd = re.search(r'Direct deposit required:.*', glance, re.I).group()
        
        if_dd = np.nan
        try:
            match = re.search(r':\s*no', dd, re.I)
            if match:
                if_dd = 0
            else:
                if_dd = 1
        except:
            if_dd = np.nan
        
        if if_dd == 1:
            amount = np.nan
            try:
                amount = re.sub(r'\,', '', dd, re.I)
                amount = re.findall(r'\$\d+', amount, re.I)
                for i in range(len(amount)):
                    amount[i] = re.sub(r'\$', '', amount[i])
                amount = np.max(list(map(float, amount)))
            except:
                amount = np.nan

            count_dict = {'one': 1, 'two': 2, 'three': 3, 'four': 4, 'five': 5, 'six': 6, 'seven': 7, 
                          'eight': 8, 'nine': 9, 'ten': 10, 'eleven': 11, 'twelve': 12}
            pattern = r'one|two|three|four|five|six|seven|eight|nine|ten|eleven|twelve'

            count = 0 
            total = 0 

            try:
                count = re.search(pattern, dd, re.I)
                if count:
                    count = np.max([count_dict[c.lower()] for c in count.group().split()])
                else:
                    try:
                        match_days = re.search(r'day', dd, re.I)
                        if match_days:
                            match_days = re.search(r' (\d+) ', dd, re.I)
                            match_days = np.max(list(map(float, match_days.group().split())))/30
                            count = int(match_days)
                        else:
                            count = np.nan
                    except:
                        count = np.nan
            except:
                count = np.nan

            try:
                match_total = re.search(r'total', dd, re.I)     
                if match_total:
                    total = 1
                    try:
                        amount = amount/count
                    except:
                        print('wrong')
                else:
                    total = 0
            except:
                total = 0

            return amount, count
        else:
            return np.nan, np.nan
    except:
        return np.nan, np.nan

# %%
cols = ['dd_amount_per_time', 'dd_total_time']
cols = list(map(lambda x: 'glance_'+x, cols))
cols
# Out:
# ['glance_dd_amount_per_time', 'glance_dd_total_time']

# %%
bonus_posts_df['glance_tmp'] = bonus_posts_df['glance'].apply(get_dd_from_glance)
bonus_posts_df
# Out:
#                                                  title  \
# 0                  Chesapeake Bank $100 Savings Bonus
# 1            Arsenal Credit Union $100 Checking Bonus
# 2             The Cooperative Bank $200 Checking Bonus
# 3                  Old Second Bank $200 Checking Bonus
# 4    BBVA $400 Checking Bonus + $50 Savings Bonus &...
# ..                                                 ...
# 208  Sharepoint Credit Union $150 Checking Bonus + ...
# 209             Addition Financial $300 Checking Bonus
# 210            Monson Savings Bank $100 Checking Bonus
# 211           BMO Harris $700 Checking & Savings Bonus
# 212            Mazuma Credit Union $200 Checking Bonus
#
#                                              post_link  \
# 0    https://www.doctorofcredit.com/va-only-chesape...
# 1    https://www.doctorofcredit.com/mo-only-arsenal...
# 2    https://www.doctorofcredit.com/ma-only-the-coo...
# 3    https://www.doctorofcredit.com/il-only-old-sec...
# 4    https://www.doctorofcredit.com/bbva-400-checki...
# ..                                                 ...
# 208  https://www.doctorofcredit.com/mn-sharepoint-c...
# 209  https://www.doctorofcredit.com/fl-only-additio...
# 210  https://www.doctorofcredit.com/ma-in-branch-mo...
# 211  https://www.doctorofcredit.com/il-wi-mn-in-bmo...
# 212  https://www.doctorofcredit.com/ks-mo-mazuma-cr...
#
#                                                 glance  \
# 0    Maximum bonus amount: $100\nAvailability: VA o...
# 1    Maximum bonus amount: $100\nAvailability: MO o...
# 2    Maximum bonus amount: $200\nAvailability: MA o...
# 3    Maximum bonus amount: $200\nAvailability:Must ...
# 4    Maximum bonus amount: $450\nAvailability: Nati...
# ..                                                 ...
# 208  Maximum bonus amount: $150\nAvailability: MN o...
# 209  Maximum bonus amount: $300\nAvailability: Must...
# 210  Maximum bonus amount: $100\nAvailability: In b...
# 211  Maximum bonus amount: $700\nAvailability: you ...
# 212  Maximum bonus amount: $200\nAvailability: Must...
#
#                                                  offer  \
# 0    Chesapeake Bank is offering a bonus of $100 wh...
# 1    Arsenal Credit Union is offering a bonus of $1...
# 2    The Cooperative Bank is offering a bonus of $2...
# 3    Old Second Bank is offering a $200 checking bo...
# 4    BBVA Compass is offering a checking bonus of $...
# ..                                                 ...
# 208  Sharepoint Credit Union is offering a bonus of...
# 209  Addition Financial is offering a bonus of $300...
# 210  Monson Savings Bank is offering a bonus of $10...
# 211  BMO Harris is offering a bonus of up to $700 w...
# 212  Mazuma Credit Union is offering a bonus of $20...
#
#                                                    fee  bonus     glance_tmp
# 0    The totally free checking account has no month...  100.0     (nan, nan)
# 1    This account has no monthly fees to worry abou...  100.0     (nan, nan)
# 2    This account has a $10 monthly fee, this is wa...  200.0     (250.0, 2)
# 3    Money connection account has a $3.95 fee if yo...  200.0     (nan, nan)
# 4    If you live in AL, AZ, CA, CO, FL NM or TX the...  450.0  (2500.0, nan)
# ..                                                 ...    ...            ...
# 208  Account comes with a $5.95 monthly fee, this i...  150.0   (300.0, nan)
# 209  Looks like there is a $10 membership fee, not ...  300.0     (nan, nan)
# 210  They offer a free checking account with no mon...  100.0   (500.0, nan)
# 211  Your best option is to open the BMO Smart Adva...  700.0     (nan, nan)
# 212  The classic checking account has no monthly fe...  200.0     (nan, nan)
#
# [213 rows x 7 columns]

# %%
bonus_posts_df[cols] = pd.DataFrame(bonus_posts_df['glance_tmp'].values.tolist(), index= bonus_posts_df.index)

bonus_posts_df.head()
# Out:
#                                                title  \
# 0                Chesapeake Bank $100 Savings Bonus
# 1          Arsenal Credit Union $100 Checking Bonus
# 2           The Cooperative Bank $200 Checking Bonus
# 3                Old Second Bank $200 Checking Bonus
# 4  BBVA $400 Checking Bonus + $50 Savings Bonus &...
#
#                                            post_link  \
# 0  https://www.doctorofcredit.com/va-only-chesape...
# 1  https://www.doctorofcredit.com/mo-only-arsenal...
# 2  https://www.doctorofcredit.com/ma-only-the-coo...
# 3  https://www.doctorofcredit.com/il-only-old-sec...
# 4  https://www.doctorofcredit.com/bbva-400-checki...
#
#                                               glance  \
# 0  Maximum bonus amount: $100\nAvailability: VA o...
# 1  Maximum bonus amount: $100\nAvailability: MO o...
# 2  Maximum bonus amount: $200\nAvailability: MA o...
# 3  Maximum bonus amount: $200\nAvailability:Must ...
# 4  Maximum bonus amount: $450\nAvailability: Nati...
#
#                                                offer  \
# 0  Chesapeake Bank is offering a bonus of $100 wh...
# 1  Arsenal Credit Union is offering a bonus of $1...
# 2  The Cooperative Bank is offering a bonus of $2...
# 3  Old Second Bank is offering a $200 checking bo...
# 4  BBVA Compass is offering a checking bonus of $...
#
#                                                  fee  bonus     glance_tmp  \
# 0  The totally free checking account has no month...  100.0     (nan, nan)
# 1  This account has no monthly fees to worry abou...  100.0     (nan, nan)
# 2  This account has a $10 monthly fee, this is wa...  200.0     (250.0, 2)
# 3  Money connection account has a $3.95 fee if yo...  200.0     (nan, nan)
# 4  If you live in AL, AZ, CA, CO, FL NM or TX the...  450.0  (2500.0, nan)
#
#    glance_dd_amount_per_time  glance_dd_total_time
# 0                        NaN                   NaN
# 1                        NaN                   NaN
# 2                      250.0                   2.0
# 3                        NaN                   NaN
# 4                     2500.0                   NaN

# %% [markdown]
# #### get expiration date from glance

# %%
def get_expir_date(glance):
    try:
        expir_date = re.search(r'expiration date:.*', glance, re.I)
        expir_date = re.sub(r'[Ee]xpiration [Dd]ate:\s*', '', expir_date.group(), re.I)
        expir_date = re.sub(r'\,', '', expir_date)
        expir_date = re.sub(r'[/-]', ' ', expir_date)
        expir_date = re.findall(r'(\w+\s\w+\s\w+)', expir_date, re.I)
        
        try:
            return np.max([pd.to_datetime(day) for day in expir_date])
        except:
            return np.nan
    except:
        return np.nan

bonus_posts_df['expiration_date'] = bonus_posts_df['glance'].apply(get_expir_date)
bonus_posts_df.head()
# Out:
#                                                title  \
# 0                Chesapeake Bank $100 Savings Bonus
# 1          Arsenal Credit Union $100 Checking Bonus
# 2           The Cooperative Bank $200 Checking Bonus
# 3                Old Second Bank $200 Checking Bonus
# 4  BBVA $400 Checking Bonus + $50 Savings Bonus &...
#
#                                            post_link  \
# 0  https://www.doctorofcredit.com/va-only-chesape...
# 1  https://www.doctorofcredit.com/mo-only-arsenal...
# 2  https://www.doctorofcredit.com/ma-only-the-coo...
# 3  https://www.doctorofcredit.com/il-only-old-sec...
# 4  https://www.doctorofcredit.com/bbva-400-checki...
#
#                                               glance  \
# 0  Maximum bonus amount: $100\nAvailability: VA o...
# 1  Maximum bonus amount: $100\nAvailability: MO o...
# 2  Maximum bonus amount: $200\nAvailability: MA o...
# 3  Maximum bonus amount: $200\nAvailability:Must ...
# 4  Maximum bonus amount: $450\nAvailability: Nati...
#
#                                                offer  \
# 0  Chesapeake Bank is offering a bonus of $100 wh...
# 1  Arsenal Credit Union is offering a bonus of $1...
# 2  The Cooperative Bank is offering a bonus of $2...
# 3  Old Second Bank is offering a $200 checking bo...
# 4  BBVA Compass is offering a checking bonus of $...
#
#                                                  fee  bonus     glance_tmp  \
# 0  The totally free checking account has no month...  100.0     (nan, nan)
# 1  This account has no monthly fees to worry abou...  100.0     (nan, nan)
# 2  This account has a $10 monthly fee, this is wa...  200.0     (250.0, 2)
# 3  Money connection account has a $3.95 fee if yo...  200.0     (nan, nan)
# 4  If you live in AL, AZ, CA, CO, FL NM or TX the...  450.0  (2500.0, nan)
#
#    glance_dd_amount_per_time  glance_dd_total_time expiration_date
# 0                        NaN                   NaN      2020-04-30
# 1                        NaN                   NaN      2020-03-31
# 2                      250.0                   2.0      2020-02-28
# 3                        NaN                   NaN      2020-04-30
# 4                     2500.0                   NaN      2020-02-10

# %%
# glances = list(bonus_posts_df['glance'])

def get_termin_time_from_glance(glance):
    count_dict = {'one': 1, 'two': 2, 'three': 3, 'four': 4, 'five': 5, 'six': 6, 'seven': 7, 
                  'eight': 8, 'nine': 9, 'ten': 10, 'eleven': 11, 'twelve': 12}
    pattern = r'one|two|three|four|five|six|seven|eight|nine|ten|eleven|twelve'
    count = 0
    try:
        term = re.search(r'.*termination.*', glance, re.I)
        term = re.sub(r'[Ee]arly account termination fee:\s*', '', term.group(), re.I)

        match_year = re.search(r'year', term, re.I)
        if match_year:           
            try:
                count = re.search(r'(\w) year', term, re.I)
                count = re.search(r'(\d+)', term.group(), re.I)
                count = min(list(map(float, count.group().split())))*12
            except:
                count = re.search(pattern, term, re.I)
                if count:
                    count = max([count_dict[c.lower()] for c in count.group().split()])*12
                    
        match_months = re.search(r'month', term, re.I)
        if match_months:           
            try:
                count = re.search(r'(\w) month', term, re.I)
                count = re.search(r'(\d+)', term.group(), re.I)
                count = min(list(map(float, count.group().split())))
            except:
                count = re.search(pattern, term, re.I)
                if count:
                    count = max([count_dict[c.lower()] for c in count.group().split()])
                    
        match_days = re.search(r'day', term, re.I)
        if match_days:
            match_days = re.search(r' (\d+) ', term, re.I)
            count = max(list(map(float, match_days.group().split())))/30
        return int(count)
    except:
        return np.nan

bonus_posts_df['glance_keeping_time'] = bonus_posts_df['glance'].apply(get_termin_time_from_glance)
bonus_posts_df.head()

# for i in range(len(glances)):
#     get_termin_time_from_glance(glances[i])
#     print()
# Out:
#                                                title  \
# 0                Chesapeake Bank $100 Savings Bonus
# 1          Arsenal Credit Union $100 Checking Bonus
# 2           The Cooperative Bank $200 Checking Bonus
# 3                Old Second Bank $200 Checking Bonus
# 4  BBVA $400 Checking Bonus + $50 Savings Bonus &...
#
#                                            post_link  \
# 0  https://www.doctorofcredit.com/va-only-chesape...
# 1  https://www.doctorofcredit.com/mo-only-arsenal...
# 2  https://www.doctorofcredit.com/ma-only-the-coo...
# 3  https://www.doctorofcredit.com/il-only-old-sec...
# 4  https://www.doctorofcredit.com/bbva-400-checki...
#
#                                               glance  \
# 0  Maximum bonus amount: $100\nAvailability: VA o...
# 1  Maximum bonus amount: $100\nAvailability: MO o...
# 2  Maximum bonus amount: $200\nAvailability: MA o...
# 3  Maximum bonus amount: $200\nAvailability:Must ...
# 4  Maximum bonus amount: $450\nAvailability: Nati...
#
#                                                offer  \
# 0  Chesapeake Bank is offering a bonus of $100 wh...
# 1  Arsenal Credit Union is offering a bonus of $1...
# 2  The Cooperative Bank is offering a bonus of $2...
# 3  Old Second Bank is offering a $200 checking bo...
# 4  BBVA Compass is offering a checking bonus of $...
#
#                                                  fee  bonus     glance_tmp  \
# 0  The totally free checking account has no month...  100.0     (nan, nan)
# 1  This account has no monthly fees to worry abou...  100.0     (nan, nan)
# 2  This account has a $10 monthly fee, this is wa...  200.0     (250.0, 2)
# 3  Money connection account has a $3.95 fee if yo...  200.0     (nan, nan)
# 4  If you live in AL, AZ, CA, CO, FL NM or TX the...  450.0  (2500.0, nan)
#
#    glance_dd_amount_per_time  glance_dd_total_time expiration_date  \
# 0                        NaN                   NaN      2020-04-30
# 1                        NaN                   NaN      2020-03-31
# 2                      250.0                   2.0      2020-02-28
# 3                        NaN                   NaN      2020-04-30
# 4                     2500.0                   NaN      2020-02-10
#
#    glance_keeping_time
# 0                  0.0
# 1                  3.0
# 2                  6.0
# 3                  3.0
# 4                 12.0

# %%
# bonus_posts_df[~bonus_posts_df['expiration_date'].apply(np.isnat)]

# %% [markdown]
# ### get bonus, dd amount, keep time from offer

# %%
def get_bonus_amount_from_offer(offer):
    try:
        bb = re.search(r'(bonus of.*\$\d+)|(\$\d+.*bonus)', offer, re.I)
        bb = re.sub(r'\$', '', bb.group(), re.I)
        bb = re.findall(r'\d+', bb, re.I)
        bb = max(list(map(float, bb)))
        return bb
    except:
        return np.nan
    
bonus_posts_df['offer_bonus_amount'] = bonus_posts_df['offer'].apply(get_bonus_amount_from_offer)
bonus_posts_df.head()
# Out:
#                                                title  \
# 0                Chesapeake Bank $100 Savings Bonus
# 1          Arsenal Credit Union $100 Checking Bonus
# 2           The Cooperative Bank $200 Checking Bonus
# 3                Old Second Bank $200 Checking Bonus
# 4  BBVA $400 Checking Bonus + $50 Savings Bonus &...
#
#                                            post_link  \
# 0  https://www.doctorofcredit.com/va-only-chesape...
# 1  https://www.doctorofcredit.com/mo-only-arsenal...
# 2  https://www.doctorofcredit.com/ma-only-the-coo...
# 3  https://www.doctorofcredit.com/il-only-old-sec...
# 4  https://www.doctorofcredit.com/bbva-400-checki...
#
#                                               glance  \
# 0  Maximum bonus amount: $100\nAvailability: VA o...
# 1  Maximum bonus amount: $100\nAvailability: MO o...
# 2  Maximum bonus amount: $200\nAvailability: MA o...
# 3  Maximum bonus amount: $200\nAvailability:Must ...
# 4  Maximum bonus amount: $450\nAvailability: Nati...
#
#                                                offer  \
# 0  Chesapeake Bank is offering a bonus of $100 wh...
# 1  Arsenal Credit Union is offering a bonus of $1...
# 2  The Cooperative Bank is offering a bonus of $2...
# 3  Old Second Bank is offering a $200 checking bo...
# 4  BBVA Compass is offering a checking bonus of $...
#
#                                                  fee  bonus     glance_tmp  \
# 0  The totally free checking account has no month...  100.0     (nan, nan)
# 1  This account has no monthly fees to worry abou...  100.0     (nan, nan)
# 2  This account has a $10 monthly fee, this is wa...  200.0     (250.0, 2)
# 3  Money connection account has a $3.95 fee if yo...  200.0     (nan, nan)
# 4  If you live in AL, AZ, CA, CO, FL NM or TX the...  450.0  (2500.0, nan)
#
#    glance_dd_amount_per_time  glance_dd_total_time expiration_date  \
# 0                        NaN                   NaN      2020-04-30
# 1                        NaN                   NaN      2020-03-31
# 2                      250.0                   2.0      2020-02-28
# 3                        NaN                   NaN      2020-04-30
# 4                     2500.0                   NaN      2020-02-10
#
#    glance_keeping_time  offer_bonus_amount
# 0                  0.0               100.0
# 1                  3.0               100.0
# 2                  6.0               200.0
# 3                  3.0               200.0
# 4                 12.0               400.0

# %%
def get_dd_amount_from_offer(offer):
    try:
        dd = re.search(r'(direct deposit.*\$\d+)|(\$\d+.*direct deposit)', offer, re.I)
        dd = re.sub(r'\$', '', dd.group(), re.I)
        dd = re.findall(r'\d+', dd, re.I)
        dd = max(list(map(float, dd)))
        if dd<50:
            dd = 0
        return dd
    except:
        return np.nan
    
bonus_posts_df['offer_dd_amount'] = bonus_posts_df['offer'].apply(get_dd_amount_from_offer)
bonus_posts_df.head()

# for i in range(len(bonus_posts_df)):
#     try:
#         dd = re.search(r'(direct deposit.*\$\d+)|(\$\d+.*direct deposit)', offers[i], re.I)
#         dd = re.sub(r'\$', '', dd.group(), re.I)
#         dd = re.findall(r'\d+', dd, re.I)
#         dd = max(list(map(float, dd)))
#         if dd<50:
#             dd = 0
#         return dd
#     except:
#         return np.nan

# get_dd_amount_from_offer(offers[1])
# Out:
#                                                title  \
# 0                Chesapeake Bank $100 Savings Bonus
# 1          Arsenal Credit Union $100 Checking Bonus
# 2           The Cooperative Bank $200 Checking Bonus
# 3                Old Second Bank $200 Checking Bonus
# 4  BBVA $400 Checking Bonus + $50 Savings Bonus &...
#
#                                            post_link  \
# 0  https://www.doctorofcredit.com/va-only-chesape...
# 1  https://www.doctorofcredit.com/mo-only-arsenal...
# 2  https://www.doctorofcredit.com/ma-only-the-coo...
# 3  https://www.doctorofcredit.com/il-only-old-sec...
# 4  https://www.doctorofcredit.com/bbva-400-checki...
#
#                                               glance  \
# 0  Maximum bonus amount: $100\nAvailability: VA o...
# 1  Maximum bonus amount: $100\nAvailability: MO o...
# 2  Maximum bonus amount: $200\nAvailability: MA o...
# 3  Maximum bonus amount: $200\nAvailability:Must ...
# 4  Maximum bonus amount: $450\nAvailability: Nati...
#
#                                                offer  \
# 0  Chesapeake Bank is offering a bonus of $100 wh...
# 1  Arsenal Credit Union is offering a bonus of $1...
# 2  The Cooperative Bank is offering a bonus of $2...
# 3  Old Second Bank is offering a $200 checking bo...
# 4  BBVA Compass is offering a checking bonus of $...
#
#                                                  fee  bonus     glance_tmp  \
# 0  The totally free checking account has no month...  100.0     (nan, nan)
# 1  This account has no monthly fees to worry abou...  100.0     (nan, nan)
# 2  This account has a $10 monthly fee, this is wa...  200.0     (250.0, 2)
# 3  Money connection account has a $3.95 fee if yo...  200.0     (nan, nan)
# 4  If you live in AL, AZ, CA, CO, FL NM or TX the...  450.0  (2500.0, nan)
#
#    glance_dd_amount_per_time  glance_dd_total_time expiration_date  \
# 0                        NaN                   NaN      2020-04-30
# 1                        NaN                   NaN      2020-03-31
# 2                      250.0                   2.0      2020-02-28
# 3                        NaN                   NaN      2020-04-30
# 4                     2500.0                   NaN      2020-02-10
#
#    glance_keeping_time  offer_bonus_amount  offer_dd_amount
# 0                  0.0               100.0              NaN
# 1                  3.0               100.0              NaN
# 2                  6.0               200.0            250.0
# 3                  3.0               200.0            100.0
# 4                 12.0               400.0           2020.0

# %%
def get_keep_time_from_offer(offer):
    try:
        count_day = re.search(r'\d+ days',offer, re.I)
        count_day = re.findall(r'\d+', count_day.group(), re.I)
        count_day = max(list(map(float, count_day)))/31
        return int(count_day)
    except:
        return np.nan
    
bonus_posts_df['offer_keep_time'] = bonus_posts_df['offer'].apply(get_keep_time_from_offer)
bonus_posts_df.head()
# Out:
#                                                title  \
# 0                Chesapeake Bank $100 Savings Bonus
# 1          Arsenal Credit Union $100 Checking Bonus
# 2           The Cooperative Bank $200 Checking Bonus
# 3                Old Second Bank $200 Checking Bonus
# 4  BBVA $400 Checking Bonus + $50 Savings Bonus &...
#
#                                            post_link  \
# 0  https://www.doctorofcredit.com/va-only-chesape...
# 1  https://www.doctorofcredit.com/mo-only-arsenal...
# 2  https://www.doctorofcredit.com/ma-only-the-coo...
# 3  https://www.doctorofcredit.com/il-only-old-sec...
# 4  https://www.doctorofcredit.com/bbva-400-checki...
#
#                                               glance  \
# 0  Maximum bonus amount: $100\nAvailability: VA o...
# 1  Maximum bonus amount: $100\nAvailability: MO o...
# 2  Maximum bonus amount: $200\nAvailability: MA o...
# 3  Maximum bonus amount: $200\nAvailability:Must ...
# 4  Maximum bonus amount: $450\nAvailability: Nati...
#
#                                                offer  \
# 0  Chesapeake Bank is offering a bonus of $100 wh...
# 1  Arsenal Credit Union is offering a bonus of $1...
# 2  The Cooperative Bank is offering a bonus of $2...
# 3  Old Second Bank is offering a $200 checking bo...
# 4  BBVA Compass is offering a checking bonus of $...
#
#                                                  fee  bonus     glance_tmp  \
# 0  The totally free checking account has no month...  100.0     (nan, nan)
# 1  This account has no monthly fees to worry abou...  100.0     (nan, nan)
# 2  This account has a $10 monthly fee, this is wa...  200.0     (250.0, 2)
# 3  Money connection account has a $3.95 fee if yo...  200.0     (nan, nan)
# 4  If you live in AL, AZ, CA, CO, FL NM or TX the...  450.0  (2500.0, nan)
#
#    glance_dd_amount_per_time  glance_dd_total_time expiration_date  \
# 0                        NaN                   NaN      2020-04-30
# 1                        NaN                   NaN      2020-03-31
# 2                      250.0                   2.0      2020-02-28
# 3                        NaN                   NaN      2020-04-30
# 4                     2500.0                   NaN      2020-02-10
#
#    glance_keeping_time  offer_bonus_amount  offer_dd_amount  offer_keep_time
# 0                  0.0               100.0              NaN              NaN
# 1                  3.0               100.0              NaN              0.0
# 2                  6.0               200.0            250.0              2.0
# 3                  3.0               200.0            100.0              NaN
# 4                 12.0               400.0           2020.0              NaN

# %% [markdown]
# ### get keeping time from fees

# %%
fees = bonus_posts_df['fee']

def get_keep_time_from_fee(fee):
    try:
        count_day = re.search(r'\d+ days', fee, re.I)
        count_day = re.findall(r'\d+', count_day.group(), re.I)
        count_day = max(list(map(float, count_day)))/31
        return int(count_day)
    except:
        return np.nan
    
bonus_posts_df['fee_keep_time'] = bonus_posts_df['offer'].apply(get_keep_time_from_fee)
bonus_posts_df.head()
        


# get_dd_amount_from_offer(offers[1])
# Out:
#                                                title  \
# 0                Chesapeake Bank $100 Savings Bonus
# 1          Arsenal Credit Union $100 Checking Bonus
# 2           The Cooperative Bank $200 Checking Bonus
# 3                Old Second Bank $200 Checking Bonus
# 4  BBVA $400 Checking Bonus + $50 Savings Bonus &...
#
#                                            post_link  \
# 0  https://www.doctorofcredit.com/va-only-chesape...
# 1  https://www.doctorofcredit.com/mo-only-arsenal...
# 2  https://www.doctorofcredit.com/ma-only-the-coo...
# 3  https://www.doctorofcredit.com/il-only-old-sec...
# 4  https://www.doctorofcredit.com/bbva-400-checki...
#
#                                               glance  \
# 0  Maximum bonus amount: $100\nAvailability: VA o...
# 1  Maximum bonus amount: $100\nAvailability: MO o...
# 2  Maximum bonus amount: $200\nAvailability: MA o...
# 3  Maximum bonus amount: $200\nAvailability:Must ...
# 4  Maximum bonus amount: $450\nAvailability: Nati...
#
#                                                offer  \
# 0  Chesapeake Bank is offering a bonus of $100 wh...
# 1  Arsenal Credit Union is offering a bonus of $1...
# 2  The Cooperative Bank is offering a bonus of $2...
# 3  Old Second Bank is offering a $200 checking bo...
# 4  BBVA Compass is offering a checking bonus of $...
#
#                                                  fee  bonus     glance_tmp  \
# 0  The totally free checking account has no month...  100.0     (nan, nan)
# 1  This account has no monthly fees to worry abou...  100.0     (nan, nan)
# 2  This account has a $10 monthly fee, this is wa...  200.0     (250.0, 2)
# 3  Money connection account has a $3.95 fee if yo...  200.0     (nan, nan)
# 4  If you live in AL, AZ, CA, CO, FL NM or TX the...  450.0  (2500.0, nan)
#
#    glance_dd_amount_per_time  glance_dd_total_time expiration_date  \
# 0                        NaN                   NaN      2020-04-30
# 1                        NaN                   NaN      2020-03-31
# 2                      250.0                   2.0      2020-02-28
# 3                        NaN                   NaN      2020-04-30
# 4                     2500.0                   NaN      2020-02-10
#
#    glance_keeping_time  offer_bonus_amount  offer_dd_amount  offer_keep_time  \
# 0                  0.0               100.0              NaN              NaN
# 1                  3.0               100.0              NaN              0.0
# 2                  6.0               200.0            250.0              2.0
# 3                  3.0               200.0            100.0              NaN
# 4                 12.0               400.0           2020.0              NaN
#
#    fee_keep_time
# 0            NaN
# 1            0.0
# 2            2.0
# 3            NaN
# 4            NaN

# %% [markdown]
# ### combine features and clean dataframe

# %%
df = bonus_posts_df

# %%
df['bonus'].fillna(df['offer_bonus_amount'], inplace=True)

# %%
df['monthly_dd'] = df['glance_dd_amount_per_time'].map(str) + ' ' + df['offer_dd_amount'].map(str)
df['monthly_dd'] = df['monthly_dd'].apply(lambda x: max(list(map(float, x.split()))))

# %%
df['glance_dd_total_time'].fillna(0, inplace=True)
df['glance_keeping_time'].fillna(0, inplace=True)
df['offer_keep_time'].fillna(0, inplace=True)
df['fee_keep_time'].fillna(0, inplace=True)

# %%
df['keep_time'] = df['glance_dd_total_time'].map(str) + ' ' + df['glance_keeping_time'].map(str)
df['keep_time'] = df['keep_time'].map(str) + ' ' + df['offer_keep_time'].map(str)
df['keep_time'] = df['keep_time'].map(str) + ' ' + df['fee_keep_time'].map(str)
df['keep_time'] = df['keep_time'].apply(lambda x: max(list(map(float, x.split()))))

# %%
df
# Out:
#                                                  title  \
# 0                  Chesapeake Bank $100 Savings Bonus
# 1            Arsenal Credit Union $100 Checking Bonus
# 2             The Cooperative Bank $200 Checking Bonus
# 3                  Old Second Bank $200 Checking Bonus
# 4    BBVA $400 Checking Bonus + $50 Savings Bonus &...
# ..                                                 ...
# 208  Sharepoint Credit Union $150 Checking Bonus + ...
# 209             Addition Financial $300 Checking Bonus
# 210            Monson Savings Bank $100 Checking Bonus
# 211           BMO Harris $700 Checking & Savings Bonus
# 212            Mazuma Credit Union $200 Checking Bonus
#
#                                              post_link  \
# 0    https://www.doctorofcredit.com/va-only-chesape...
# 1    https://www.doctorofcredit.com/mo-only-arsenal...
# 2    https://www.doctorofcredit.com/ma-only-the-coo...
# 3    https://www.doctorofcredit.com/il-only-old-sec...
# 4    https://www.doctorofcredit.com/bbva-400-checki...
# ..                                                 ...
# 208  https://www.doctorofcredit.com/mn-sharepoint-c...
# 209  https://www.doctorofcredit.com/fl-only-additio...
# 210  https://www.doctorofcredit.com/ma-in-branch-mo...
# 211  https://www.doctorofcredit.com/il-wi-mn-in-bmo...
# 212  https://www.doctorofcredit.com/ks-mo-mazuma-cr...
#
#                                                 glance  \
# 0    Maximum bonus amount: $100\nAvailability: VA o...
# 1    Maximum bonus amount: $100\nAvailability: MO o...
# 2    Maximum bonus amount: $200\nAvailability: MA o...
# 3    Maximum bonus amount: $200\nAvailability:Must ...
# 4    Maximum bonus amount: $450\nAvailability: Nati...
# ..                                                 ...
# 208  Maximum bonus amount: $150\nAvailability: MN o...
# 209  Maximum bonus amount: $300\nAvailability: Must...
# 210  Maximum bonus amount: $100\nAvailability: In b...
# 211  Maximum bonus amount: $700\nAvailability: you ...
# 212  Maximum bonus amount: $200\nAvailability: Must...
#
#                                                  offer  \
# 0    Chesapeake Bank is offering a bonus of $100 wh...
# 1    Arsenal Credit Union is offering a bonus of $1...
# 2    The Cooperative Bank is offering a bonus of $2...
# 3    Old Second Bank is offering a $200 checking bo...
# 4    BBVA Compass is offering a checking bonus of $...
# ..                                                 ...
# 208  Sharepoint Credit Union is offering a bonus of...
# 209  Addition Financial is offering a bonus of $300...
# 210  Monson Savings Bank is offering a bonus of $10...
# 211  BMO Harris is offering a bonus of up to $700 w...
# 212  Mazuma Credit Union is offering a bonus of $20...
#
#                                                    fee  bonus     glance_tmp  \
# 0    The totally free checking account has no month...  100.0     (nan, nan)
# 1    This account has no monthly fees to worry abou...  100.0     (nan, nan)
# 2    This account has a $10 monthly fee, this is wa...  200.0     (250.0, 2)
# 3    Money connection account has a $3.95 fee if yo...  200.0     (nan, nan)
# 4    If you live in AL, AZ, CA, CO, FL NM or TX the...  450.0  (2500.0, nan)
# ..                                                 ...    ...            ...
# 208  Account comes with a $5.95 monthly fee, this i...  150.0   (300.0, nan)
# 209  Looks like there is a $10 membership fee, not ...  300.0     (nan, nan)
# 210  They offer a free checking account with no mon...  100.0   (500.0, nan)
# 211  Your best option is to open the BMO Smart Adva...  700.0     (nan, nan)
# 212  The classic checking account has no monthly fe...  200.0     (nan, nan)
#
#      glance_dd_amount_per_time  glance_dd_total_time expiration_date  \
# 0                          NaN                   0.0      2020-04-30
# 1                          NaN                   0.0      2020-03-31
# 2                        250.0                   2.0      2020-02-28
# 3                          NaN                   0.0      2020-04-30
# 4                       2500.0                   0.0      2020-02-10
# ..                         ...                   ...             ...
# 208                      300.0                   0.0      2019-09-30
# 209                        NaN                   0.0      2019-09-29
# 210                      500.0                   0.0             NaT
# 211                        NaN                   0.0      2019-08-31
# 212                        NaN                   0.0      2019-09-30
#
#      glance_keeping_time  offer_bonus_amount  offer_dd_amount  \
# 0                    0.0               100.0              NaN
# 1                    3.0               100.0              NaN
# 2                    6.0               200.0            250.0
# 3                    3.0               200.0            100.0
# 4                   12.0               400.0           2020.0
# ..                   ...                 ...              ...
# 208                  6.0               300.0            300.0
# 209                  0.0               300.0              NaN
# 210                  0.0               100.0            500.0
# 211                  3.0               700.0              0.0
# 212                  0.0               200.0              NaN
#
#      offer_keep_time  fee_keep_time  monthly_dd  keep_time
# 0                0.0            0.0         NaN        0.0
# 1                0.0            0.0         NaN        3.0
# 2                2.0            2.0       250.0        6.0
# 3                0.0            0.0         NaN        3.0
# 4                0.0            0.0      2500.0       12.0
# ..               ...            ...         ...        ...
# 208              0.0            0.0       300.0        6.0
# 209              1.0            1.0         NaN        1.0
# 210              0.0            0.0       500.0        0.0
# 211              3.0            3.0         NaN        3.0
# 212              1.0            1.0         NaN        1.0
#
# [213 rows x 17 columns]

# %%
final_cols = ['title', 'post_link', 'bonus', 'monthly_dd', 'expiration_date', 'keep_time']
df = df[final_cols]
df.head()
# Out:
#                                                title  \
# 0                Chesapeake Bank $100 Savings Bonus
# 1          Arsenal Credit Union $100 Checking Bonus
# 2           The Cooperative Bank $200 Checking Bonus
# 3                Old Second Bank $200 Checking Bonus
# 4  BBVA $400 Checking Bonus + $50 Savings Bonus &...
#
#                                            post_link  bonus  monthly_dd  \
# 0  https://www.doctorofcredit.com/va-only-chesape...  100.0         NaN
# 1  https://www.doctorofcredit.com/mo-only-arsenal...  100.0         NaN
# 2  https://www.doctorofcredit.com/ma-only-the-coo...  200.0       250.0
# 3  https://www.doctorofcredit.com/il-only-old-sec...  200.0         NaN
# 4  https://www.doctorofcredit.com/bbva-400-checki...  450.0      2500.0
#
#   expiration_date  keep_time
# 0      2020-04-30        0.0
# 1      2020-03-31        3.0
# 2      2020-02-28        6.0
# 3      2020-04-30        3.0
# 4      2020-02-10       12.0

# %%
def keeping(x):
    if x == 0:
        return 12
    return x

df['keep_time'] = df['keep_time'].apply(keeping)
df.head()
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                title  \
# 0                Chesapeake Bank $100 Savings Bonus
# 1          Arsenal Credit Union $100 Checking Bonus
# 2           The Cooperative Bank $200 Checking Bonus
# 3                Old Second Bank $200 Checking Bonus
# 4  BBVA $400 Checking Bonus + $50 Savings Bonus &...
#
#                                            post_link  bonus  monthly_dd  \
# 0  https://www.doctorofcredit.com/va-only-chesape...  100.0         NaN
# 1  https://www.doctorofcredit.com/mo-only-arsenal...  100.0         NaN
# 2  https://www.doctorofcredit.com/ma-only-the-coo...  200.0       250.0
# 3  https://www.doctorofcredit.com/il-only-old-sec...  200.0         NaN
# 4  https://www.doctorofcredit.com/bbva-400-checki...  450.0      2500.0
#
#   expiration_date  keep_time
# 0      2020-04-30       12.0
# 1      2020-03-31        3.0
# 2      2020-02-28        6.0
# 3      2020-04-30        3.0
# 4      2020-02-10       12.0

# %%
df = df[~(df['monthly_dd']==0)]

# %%
df = df.dropna()
df
# Out:
#                                                  title  \
# 2             The Cooperative Bank $200 Checking Bonus
# 4    BBVA $400 Checking Bonus + $50 Savings Bonus &...
# 6                South State Bank $200 Checking Bonus
# 9            Teachers Credit Union $200 Checking Bonus
# 11            Hancock Whitney Bank $300 Checking Bonus
# ..                                                 ...
# 196            Royal Credit Union $200 Checking Bonus
# 201             HomeTrust Bank $150 Bonus + $5 Monthly
# 203                Bank of America $350 Checking Bonus
# 207            Dedham Savings Bank $250 Checking Bonus
# 208  Sharepoint Credit Union $150 Checking Bonus + ...
#
#                                              post_link  bonus  monthly_dd  \
# 2    https://www.doctorofcredit.com/ma-only-the-coo...  200.0       250.0
# 4    https://www.doctorofcredit.com/bbva-400-checki...  450.0      2500.0
# 6    https://www.doctorofcredit.com/ga-nc-sc-south-...  200.0       250.0
# 9    https://www.doctorofcredit.com/in-mi-teachers-...  200.0       500.0
# 11   https://www.doctorofcredit.com/la-ms-fl-al-tx-...  300.0       250.0
# ..                                                 ...    ...         ...
# 196  https://www.doctorofcredit.com/mn-wi-royal-cre...  200.0       200.0
# 201  https://www.doctorofcredit.com/nc-sc-tn-va-hom...  150.0       250.0
# 203  https://www.doctorofcredit.com/id-ky-la-wi-ban...  350.0      4000.0
# 207  https://www.doctorofcredit.com/ma-only-dedham-...  250.0       500.0
# 208  https://www.doctorofcredit.com/mn-sharepoint-c...  150.0       300.0
#
#     expiration_date  keep_time
# 2        2020-02-28        6.0
# 4        2020-02-10       12.0
# 6        2019-11-30        1.0
# 9        2020-03-20       12.0
# 11       2020-03-31        6.0
# ..              ...        ...
# 196      2019-09-30        6.0
# 201      2019-11-15       12.0
# 203      2019-09-15        3.0
# 207      2019-12-31        2.0
# 208      2019-09-30        6.0
#
# [81 rows x 6 columns]

# %%
from datetime import *
time_filter = df['expiration_date']>=pd.to_datetime(datetime.today())
df = df[time_filter]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                                                 title  \
# 0            The Cooperative Bank $200 Checking Bonus
# 1   BBVA $400 Checking Bonus + $50 Savings Bonus &...
# 2           Teachers Credit Union $200 Checking Bonus
# 3            Hancock Whitney Bank $300 Checking Bonus
# 4                           HSBC $700 Checking Bonus
# 5    Seacoast Bank $350 Checking & $150 Savings Bonus
# 6                Incredible Bank $102 Checking Bonus
# 7               Bank Of The West $250 Checking Bonus
# 8   People’s United Bank $100 Checking Bonus & Sho...
# 9   Northwest Federal Credit Union $300 Checking B...
# 10                   Wells Fargo $400 Checking Bonus
# 11         Cambridge Savings Bank $400 Checking Bonus
# 12             Union Bank & Trust $150 Checking Bonus
# 13                  SunTrust $200 Checking Promotion
# 14                  Republic Bank $200 Checking Bonus
# 15      Andigo Credit Union $500 Checking Bonus + $50
# 16                 HomeTrust Bank $202 Checking Bonus
# 17                  Columbia Bank $200 Checking Bonus
# 18        Citizens Bank $600 Checking & Savings Bonus
# 19                        Keybank $200 Checking Bonus
# 20                      $300 FirstBank Checking Bonus
# 21                 Firstrust Bank $176 Checking Bonus
# 22                    PeoplesBank $200 Checking Bonus
# 23                   OneWest Bank $250 Checking Bonus
#
#                                             post_link  bonus   monthly_dd  \
# 0   https://www.doctorofcredit.com/ma-only-the-coo...  200.0   250.000000
# 1   https://www.doctorofcredit.com/bbva-400-checki...  450.0  2500.000000
# 2   https://www.doctorofcredit.com/in-mi-teachers-...  200.0   500.000000
# 3   https://www.doctorofcredit.com/la-ms-fl-al-tx-...  300.0   250.000000
# 4   https://www.doctorofcredit.com/hsbc-700-checki...  700.0   700.000000
# 5   https://www.doctorofcredit.com/fl-in-branch-on...  500.0   500.000000
# 6   https://www.doctorofcredit.com/incredible-bank...  102.0   300.000000
# 7   https://www.doctorofcredit.com/bank-of-the-wes...  250.0   333.333333
# 8   https://www.doctorofcredit.com/peoples-united-...  100.0  1000.000000
# 9   https://www.doctorofcredit.com/ballston-va-bra...  300.0   500.000000
# 10  https://www.doctorofcredit.com/wells-fargo-400...  400.0  4000.000000
# 11  https://www.doctorofcredit.com/ma-ct-me-nh-ri-...  400.0  1000.000000
# 12  https://www.doctorofcredit.com/va-md-nc-union-...  150.0  2500.000000
# 13  https://www.doctorofcredit.com/suntrust-200-ch...  200.0   500.000000
# 14  https://www.doctorofcredit.com/fl-in-ky-oh-tn-...  200.0   100.000000
# 15  https://www.doctorofcredit.com/il-only-andigo-...  500.0   500.000000
# 16  https://www.doctorofcredit.com/nc-sc-tn-va-hom...  202.0   250.000000
# 17  https://www.doctorofcredit.com/wa-or-id-in-bra...  200.0   500.000000
# 18  https://www.doctorofcredit.com/ct-de-ma-mi-nh-...  600.0   500.000000
# 19  https://www.doctorofcredit.com/unknown-locatio...  200.0   500.000000
# 20  https://www.doctorofcredit.com/ca-az-co-300-fi...  300.0   500.000000
# 21  https://www.doctorofcredit.com/de-md-nj-pa-fir...  276.0   500.000000
# 22  https://www.doctorofcredit.com/md-pa-peoplesba...  200.0   350.000000
# 23  https://www.doctorofcredit.com/southern-ca-in-...  250.0   650.000000
#
#    expiration_date  keep_time
# 0       2020-02-28        6.0
# 1       2020-02-10       12.0
# 2       2020-03-20       12.0
# 3       2020-03-31        6.0
# 4       2020-03-01        6.0
# 5       2020-04-30        3.0
# 6       2020-02-22        2.0
# 7       2020-02-28        3.0
# 8       2020-03-31        3.0
# 9       2020-02-15        3.0
# 10      2020-07-31       12.0
# 11      2020-03-31        3.0
# 12      2020-02-29        6.0
# 13      2020-03-31        2.0
# 14      2020-12-31       12.0
# 15      2020-03-31        3.0
# 16      2020-02-15        6.0
# 17      2020-02-29        3.0
# 18      2020-02-20        1.0
# 19      2020-04-24       12.0
# 20      2020-03-04        3.0
# 21      2020-04-30        2.0
# 22      2020-06-30        3.0
# 23      2020-03-31        6.0

# %%
df.to_csv('../data/real_time_bonuses.csv')
